# %%
pip install pygame
# Out:
# Collecting pygameNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 660.6 kB/s eta 0:00:17
#    ---------------------------------------- 0.1/10.6 MB 544.7 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/10.6 MB 798.9 kB/s eta 0:00:14
#     --------------------------------------- 0.2/10.6 MB 1.0 MB/s eta 0:00:11
#    - -------------------------------------- 0.3/10.6 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/10.6 MB 1.7 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/10.6 MB 2.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.1/10.6 MB 2.9 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/10.6 MB 4.3 MB/s eta 0:00:03
#    -------- ------------------------------- 2.3/10.6 MB 4.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.2/10.6 MB 6.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.4/10.6 MB 7.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.5/10.6 MB 7.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.5/10.6 MB 7.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.5/10.6 MB 7.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.6/10.6 MB 10.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.6 MB 11.6 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.6 MB 11.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 10.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.6 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 14.2 MB/s eta 0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1

# %%
import pygame

# Initialize Pygame
pygame.init()

# Initialize joystick
pygame.joystick.init()

# Check for connected joystick
if pygame.joystick.get_count() == 0:
    print("No joystick connected!")
else:
    # Get the first joystick
    joystick = pygame.joystick.Joystick(0)
    joystick.init()
    
    # Print the joystick's name and number of axes
    print("Connected to:", joystick.get_name())
    print("Number of axes:", joystick.get_numaxes())

    # Main loop to capture inputs
    running = True
    while running:
        # Handle events (necessary to capture joystick input)
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            
        # Capture and display values for each axis
        for i in range(joystick.get_numaxes()):
            axis_value = joystick.get_axis(i)
            print(f"Axis {i} value: {axis_value}")
        
        # Delay to avoid flooding the console with updates
        pygame.time.wait(1000)

# Quit Pygame when done
pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Connected to: Logitech G HUB G29 Driving Force Racing Wheel USB
# Number of axes: 4
# Axis 0 value: 0.0
# Axis 1 value: 0.0
# Axis 2 value: 0.0
# Axis 3 value: 0.0
# Axis 0 value: 0.0
# Axis 1 value: 0.0
# Axis 2 value: 0.0
# Axis 3 value: 0.0
# Axis 0 value: 0.0
# Axis 1 value: 0.0
# Axis 2 value: 0.0
# Axis 3 value: 0.0
# Axis 0 value: 0.0
# Axis 1 value: 0.0
# Axis 2 value: 0.0
# Axis 3 value: 0.0
# Axis 0 value: 0.0
# Axis 1 value: 0.0
# Axis 2 value: 0.0
# Axis 3 value: 0.0
# Axis 0 value: 0.001983642578125
# Axis 1 value: 0.999969482421875
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: -1.0
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: -0.6484375
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: -0.8515625
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: -0.1796875
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: -0.1796875
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: -0.1328125
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: 0.4603271484375
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: -0.5078125
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: -1.0
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: -0.90625
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: 0.999969482421875
# Axis 2 value: 0.746002197265625
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: 0.999969482421875
# Axis 2 value: 0.999969482421875
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: -0.515625
# Axis 2 value: -0.765625
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.001983642578125
# Axis 1 value: -0.734375
# Axis 2 value: -0.25
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.196197509765625
# Axis 1 value: -0.78125
# Axis 2 value: -0.2734375
# Axis 3 value: 0.999969482421875
# Axis 0 value: 0.32574462890625
# Axis 1 value: -0.7734375
# Axis 2 value: -0.265625
# Axis 3 value: 0.999969482421875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 35
#      32             print(f"Axis {i} value: {axis_value}")
#      34         # Delay to avoid flooding the console with updates
# ---> 35         pygame.time.wait(1000)
#      37 # Quit Pygame when done
#      38 pygame.quit()
#
# KeyboardInterrupt:
